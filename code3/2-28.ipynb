# %% [markdown]
# SEABORN FOR VISUALIZATION

# %%
import seaborn as sns

# %%
# datasets provided by seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
planets = sns.load_dataset('planets')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# SCATTER PLOT OF TIP AND TOTAL BILL

# %%
sns.scatterplot(data = tips, x='tip', y = 'total_bill', hue='day', size = 'size', palette = 'YlGnBu')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# HISTOGRAM PLOT

# %%
import matplotlib.pyplot as plt
sns.histplot(tips['tip'], kde = True, bins=30)
plt.title('Hidtogram plot for tips')
# Out:
# Text(0.5, 1.0, 'Hidtogram plot for tips')

# %% [markdown]
# DISTRIBUTION PLOT

# %%
sns.displot(tips['tip'], kde=True, bins=15)

# %%
sns.barplot(tips, x='sex', y='tip', palette='YlGnBu')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_5904\3309267698.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(tips, x='sex', y='tip', palette='YlGnBu')
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# BOXPLOT

# %%
sns.boxplot(tips, x= 'day', y = 'total_bill', hue = 'sex', palette = 'YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# STRIPPLOT

# %%
sns.stripplot(tips, x = 'day', y = 'total_bill', hue = 'sex', palette = 'YlGnBu', dodge = True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# JOINTPLOT

# %%
sns.jointplot(tips, x='tip', y ='total_bill', kind = 'hex', cmap = 'YlGnBu')

# %% [markdown]
# PAIRPLOT

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue="pclass")

# %% [markdown]
# PLOTTING CATEGORICAL DATA USING THE TRITANIC DATASET

# %%
import pandas as pd
titanic = pd.read_csv('./datasets/tested.csv')
titanic.shape
# Out:
# (418, 12)

# %%
#missing values
titanic.isnull().sum()
# titanic.drop(['Cabin'], axis= 1, inplace = True)
titanic.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
titanic['Age'].mean()
# Out:
# 30.272590361445783

# %%
titanic.describe(include = 'object').T
# Out:
#          count unique               top freq
# Name       418    418  Kelly, Mr. James    1
# Sex        418      2              male  266
# Ticket     418    363          PC 17608    5
# Embarked   418      3                 S  270

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
ax =sns.boxplot(titanic, x = "Sex", y = 'Age', palette = 'YlGnBu')
plt.title('Sex of passenger vs Age of the Passenger')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_5904\1227189000.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax =sns.boxplot(titanic, x = "Sex", y = 'Age', palette = 'YlGnBu')
# Text(0.5, 1.0, 'Sex of passenger vs Age of the Passenger')

# %%
sns.violinplot(titanic, x = "Sex", y = 'Age', palette = 'YlGnBu')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_5904\3572144056.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(titanic, x = "Sex", y = 'Age', palette = 'YlGnBu')
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.catplot(titanic, x = "Sex", y = 'Age', palette = 'YlGnBu')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_5904\7881510.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(titanic, x = "Sex", y = 'Age', palette = 'YlGnBu')

# %%
sns.stripplot(data = titanic, x ='Sex', y = 'Age', palette = 'YlGnBu')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_5904\1601430590.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data = titanic, x ='Sex', y = 'Age', palette = 'YlGnBu')
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.pairplot(titanic.select_dtypes(['number']))
