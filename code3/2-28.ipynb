# %% [markdown]
# SEABORN FOR VISUALIZATION

# %%
import seaborn as sns

# %%
# datasets provided by seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
planets = sns.load_dataset('planets')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# SCATTER PLOT OF TIP AND TOTAL BILL

# %%
sns.scatterplot(data = tips, x='tip', y = 'total_bill', hue='day', size = 'size', palette = 'YlGnBu')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# HISTOGRAM PLOT

# %%
sns.histplot(tips['tip'], kde = True, bins=30)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# DISTRIBUTION PLOT

# %%
sns.displot(tips['tip'], kde=True, bins=15)

# %%
sns.barplot(tips, x='sex', y='tip', palette='YlGnBu')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_8824\3309267698.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(tips, x='sex', y='tip', palette='YlGnBu')
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# BOXPLOT

# %%
sns.boxplot(tips, x= 'day', y = 'total_bill', hue = 'sex', palette = 'YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# STRIPPLOT

# %%
sns.stripplot(tips, x = 'day', y = 'total_bill', hue = 'sex', palette = 'YlGnBu', dodge = True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# JOINTPLOT

# %%
sns.jointplot(tips, x='tip', y ='total_bill', kind = 'hex', cmap = 'YlGnBu')

# %% [markdown]
# PAIRPLOT

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue="pclass")

# %%
sns.heatmap(titanic.corr(), annot=True, cmap="YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 sns.heatmap(titanic.corr(), annot=True, cmap="YlGnBu")
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
# ...
